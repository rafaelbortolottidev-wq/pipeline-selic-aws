# %%
import pandas as pd

df_silver = pd.read_parquet("../data/silver/selic.parquet")

print("Registros:", len(df_silver))
df_silver
# Out:
# Registros: 1186
#      data_referencia  taxa_selic_aa
# 0         2022-01-03           9.15
# 1         2022-01-04           9.15
# 2         2022-01-05           9.15
# 3         2022-01-06           9.15
# 4         2022-01-07           9.15
# ...              ...            ...
# 1181      2026-09-16          13.90
# 1182      2026-09-17          13.65
# 1183      2026-09-18          13.65
# 1184      2026-09-21          13.65
# 1185      2026-09-22          13.65
#
# [1186 rows x 2 columns]
