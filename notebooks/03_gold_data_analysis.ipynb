# %%
import pandas as pd

df_gold = pd.read_parquet("../data/gold/selic_mensal.parquet")

print("Registros:", len(df_gold))
df_gold
# Out:
# Registros: 57
#     ano_mes  taxa_media  taxa_minima  taxa_maxima  taxa_fim_mes
# 0   2022-01    9.150000         9.15         9.15          9.15
# 1   2022-02   10.492105         9.15        10.65         10.65
# 2   2022-03   11.150000        10.65        11.65         11.65
# 3   2022-04   11.650000        11.65        11.65         11.65
# 4   2022-05   12.513636        11.65        12.65         12.65
# 5   2022-06   12.888095        12.65        13.15         13.15
# 6   2022-07   13.150000        13.15        13.15         13.15
# 7   2022-08   13.584783        13.15        13.65         13.65
# 8   2022-09   13.650000        13.65        13.65         13.65
# 9   2022-10   13.650000        13.65        13.65         13.65
# 10  2022-11   13.650000        13.65        13.65         13.65
# 11  2022-12   13.650000        13.65        13.65         13.65
# 12  2023-01   13.650000        13.65        13.65         13.65
# ...
